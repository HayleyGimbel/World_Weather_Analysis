# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config2 import weather_api_key
from datetime import datetime
from scipy import stats

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0eb8a9a36f66204a6c181b6165f05eed

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | san luis
# Processing Record 7 of Set 1 | banda aceh
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | ayan
# Processing Record 12 of Set 1 | salalah
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | yerbogachen
# Processing Record 16 of Set 1 | roma
# Processing Record 17 of Set 1 | clyde river
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | kavieng
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | alofi
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | klaksvik
# Processing Record 27 of Set 1 | labuhan
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | brae
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | birao
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | stokmarknes
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | rio grande
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | flin flon
# Processing Record 44 of Set 1 | port hedland
# Processing Record 45 of Set 1 | gambela
# Processing Record 46 of Set 1 | ardakan
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | filadelfia
# Processing Record 50 of Set 1 | tottori
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | hastings
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | richmond
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | hokitika
# Processing Record 9 of Set 2 | starokostyantyniv
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 2 | marzuq
# Processing Record 13 of Set 2 | diego de almagro
# Processing Record 14 of Set 2 | zhezkazgan
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | roald
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | mahebourg
# Processing Record 20 of Set 2 | soma
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | kaman
# Processing Record 23 of Set 2 | kara
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | port-cartier
# Processing Record 26 of Set 2 | porto empedocle
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | thiruvananthapuram
# Processing Record 30 of Set 2 | marsh harbour
# Processing Record 31 of Set 2 | sobolevo
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | port shepstone
# Processing Record 36 of Set 2 | beyneu
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | komsomolskiy
# Processing Record 39 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | merauke
# Processing Record 42 of Set 2 | nizwa
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | singapore
# Processing Record 46 of Set 2 | sakaiminato
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | lorengau
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | muhos
# Processing Record 5 of Set 3 | busselton
# Processing Record 6 of Set 3 | pevek
# Processing Record 7 of Set 3 | tiznit
# Processing Record 8 of Set 3 | svetlogorsk
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | nassau
# Processing Record 11 of Set 3 | devarkonda
# Processing Record 12 of Set 3 | hami
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | camacha
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | cobija
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | adony
# Processing Record 20 of Set 3 | harper
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | araouane
# Processing Record 23 of Set 3 | samaipata
# Processing Record 24 of Set 3 | bonavista
# Processing Record 25 of Set 3 | comarapa
# Processing Record 26 of Set 3 | bandarbeyla
# Processing Record 27 of Set 3 | gwanda
# Processing Record 28 of Set 3 | aklavik
# Processing Record 29 of Set 3 | port augusta
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | guia de isora
# Processing Record 32 of Set 3 | las palmas
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | mayo
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | north bend
# Processing Record 39 of Set 3 | nieves
# Processing Record 40 of Set 3 | ostrovnoy
# Processing Record 41 of Set 3 | santa fe
# Processing Record 42 of Set 3 | chifeng
# Processing Record 43 of Set 3 | caxito
# Processing Record 44 of Set 3 | plouzane
# Processing Record 45 of Set 3 | mizdah
# Processing Record 46 of Set 3 | amapa
# Processing Record 47 of Set 3 | lillooet
# Processing Record 48 of Set 3 | muravlenko
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | tuktoyaktuk
# Processing Record 1 of Set 4 | vanavara
# Processing Record 2 of Set 4 | dukat
# Processing Record 3 of Set 4 | pitimbu
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | mbanza-ngungu
# Processing Record 6 of Set 4 | lalawigan
# Processing Record 7 of Set 4 | tokomaru
# Processing Record 8 of Set 4 | hofn
# Processing Record 9 of Set 4 | vaitape
# Processing Record 10 of Set 4 | taltal
# Processing Record 11 of Set 4 | bangassou
# Processing Record 12 of Set 4 | taoudenni
# Processing Record 13 of Set 4 | bedesa
# Processing Record 14 of Set 4 | puerto gaitan
# Processing Record 15 of Set 4 | tilichiki
# Processing Record 16 of Set 4 | greensburg
# Processing Record 17 of Set 4 | nyaunglebin
# Processing Record 18 of Set 4 | ialibu
# Processing Record 19 of Set 4 | juan aldama
# Processing Record 20 of Set 4 | mansa
# Processing Record 21 of Set 4 | fairbanks
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | imbituba
# Processing Record 24 of Set 4 | nishihara
# Processing Record 25 of Set 4 | salinopolis
# Processing Record 26 of Set 4 | bloemfontein
# Processing Record 27 of Set 4 | oussouye
# Processing Record 28 of Set 4 | altamira
# Processing Record 29 of Set 4 | chokurdakh
# Processing Record 30 of Set 4 | ocampo
# Processing Record 31 of Set 4 | carroll
# Processing Record 32 of Set 4 | alice
# Processing Record 33 of Set 4 | oxford
# Processing Record 34 of Set 4 | muli
# Processing Record 35 of Set 4 | kamaishi
# Processing Record 36 of Set 4 | diffa
# Processing Record 37 of Set 4 | okhotsk
# Processing Record 38 of Set 4 | karpogory
# Processing Record 39 of Set 4 | ashoknagar
# Processing Record 40 of Set 4 | sarh
# Processing Record 41 of Set 4 | gat
# Processing Record 42 of Set 4 | sisimiut
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | haines junction
# Processing Record 45 of Set 4 | pauini
# Processing Record 46 of Set 4 | namatanai
# Processing Record 47 of Set 4 | waingapu
# Processing Record 48 of Set 4 | comodoro rivadavia
# Processing Record 49 of Set 4 | cacu
# Processing Record 50 of Set 4 | himensulan
# Processing Record 1 of Set 5 | kijang
# Processing Record 2 of Set 5 | acari
# Processing Record 3 of Set 5 | buenos aires
# Processing Record 4 of Set 5 | ionia
# Processing Record 5 of Set 5 | tabou
# Processing Record 6 of Set 5 | zyryanka
# Processing Record 7 of Set 5 | petropavl
# Processing Record 8 of Set 5 | papasquiaro
# City not found. Skipping...
# Processing Record 9 of Set 5 | kobryn
# Processing Record 10 of Set 5 | libourne
# Processing Record 11 of Set 5 | krasavino
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 5 | tsogni
# Processing Record 15 of Set 5 | murray bridge
# Processing Record 16 of Set 5 | isangel
# Processing Record 17 of Set 5 | christchurch
# Processing Record 18 of Set 5 | puerto leguizamo
# Processing Record 19 of Set 5 | kaili
# Processing Record 20 of Set 5 | baykit
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | santa cruz cabralia
# Processing Record 23 of Set 5 | los llanos de aridane
# Processing Record 24 of Set 5 | mandalgovi
# Processing Record 25 of Set 5 | zhigansk
# Processing Record 26 of Set 5 | hambantota
# Processing Record 27 of Set 5 | krasnystaw
# Processing Record 28 of Set 5 | ambilobe
# Processing Record 29 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 5 | new norfolk
# Processing Record 31 of Set 5 | nantucket
# Processing Record 32 of Set 5 | orlik
# Processing Record 33 of Set 5 | pacific grove
# Processing Record 34 of Set 5 | conceicao das alagoas
# Processing Record 35 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 5 | pinega
# Processing Record 37 of Set 5 | shimoda
# Processing Record 38 of Set 5 | san quintin
# Processing Record 39 of Set 5 | innisfail
# Processing Record 40 of Set 5 | urumqi
# Processing Record 41 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 5 | pangnirtung
# Processing Record 43 of Set 5 | laguna
# Processing Record 44 of Set 5 | northam
# Processing Record 45 of Set 5 | ordu
# Processing Record 46 of Set 5 | port hardy
# Processing Record 47 of Set 5 | katsuura
# Processing Record 48 of Set 5 | puerto madero
# Processing Record 49 of Set 5 | kaeo
# Processing Record 50 of Set 5 | cockburn town
# Processing Record 1 of Set 6 | saskylakh
# Processing Record 2 of Set 6 | anan
# Processing Record 3 of Set 6 | gamba
# Processing Record 4 of Set 6 | dingle
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | palmer
# Processing Record 7 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 6 | itumbiara
# Processing Record 9 of Set 6 | sao gabriel da cachoeira
# Processing Record 10 of Set 6 | frontera
# Processing Record 11 of Set 6 | kahului
# Processing Record 12 of Set 6 | tuatapere
# Processing Record 13 of Set 6 | sao filipe
# Processing Record 14 of Set 6 | avera
# Processing Record 15 of Set 6 | dharchula
# Processing Record 16 of Set 6 | auki
# Processing Record 17 of Set 6 | walvis bay
# Processing Record 18 of Set 6 | wenling
# Processing Record 19 of Set 6 | tibu
# Processing Record 20 of Set 6 | beringovskiy
# Processing Record 21 of Set 6 | chara
# Processing Record 22 of Set 6 | byron bay
# Processing Record 23 of Set 6 | talara
# Processing Record 24 of Set 6 | keuruu
# Processing Record 25 of Set 6 | letlhakane
# Processing Record 26 of Set 6 | coquimbo
# Processing Record 27 of Set 6 | cloquet
# Processing Record 28 of Set 6 | fayaoue
# Processing Record 29 of Set 6 | wittlich
# Processing Record 30 of Set 6 | prince rupert
# Processing Record 31 of Set 6 | atar
# Processing Record 32 of Set 6 | kargasok
# Processing Record 33 of Set 6 | fuerte olimpo
# Processing Record 34 of Set 6 | kalmunai
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | yulara
# Processing Record 37 of Set 6 | naifaru
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 40 of Set 6 | killarney
# Processing Record 41 of Set 6 | lavrentiya
# Processing Record 42 of Set 6 | makokou
# Processing Record 43 of Set 6 | luanda
# Processing Record 44 of Set 6 | ixtapa
# Processing Record 45 of Set 6 | burica
# City not found. Skipping...
# Processing Record 46 of Set 6 | longyearbyen
# Processing Record 47 of Set 6 | vinukonda
# Processing Record 48 of Set 6 | kashi
# Processing Record 49 of Set 6 | bereda
# Processing Record 50 of Set 6 | saint-philippe
# Processing Record 1 of Set 7 | hit
# Processing Record 2 of Set 7 | ryde
# Processing Record 3 of Set 7 | omboue
# Processing Record 4 of Set 7 | trelew
# Processing Record 5 of Set 7 | cherskiy
# Processing Record 6 of Set 7 | sabang
# Processing Record 7 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 7 | nelson bay
# Processing Record 9 of Set 7 | gwadar
# Processing Record 10 of Set 7 | turukhansk
# Processing Record 11 of Set 7 | berlevag
# Processing Record 12 of Set 7 | olafsvik
# Processing Record 13 of Set 7 | ilulissat
# Processing Record 14 of Set 7 | turan
# Processing Record 15 of Set 7 | boa vista
# Processing Record 16 of Set 7 | pravia
# Processing Record 17 of Set 7 | kloulklubed
# Processing Record 18 of Set 7 | oia
# Processing Record 19 of Set 7 | saint-augustin
# Processing Record 20 of Set 7 | poya
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | kamenka
# Processing Record 23 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 7 | pangai
# Processing Record 25 of Set 7 | lazaro cardenas
# Processing Record 26 of Set 7 | lashio
# Processing Record 27 of Set 7 | natal
# Processing Record 28 of Set 7 | sao joao da barra
# Processing Record 29 of Set 7 | belmonte
# Processing Record 30 of Set 7 | matagami
# Processing Record 31 of Set 7 | imeni babushkina
# Processing Record 32 of Set 7 | malakal
# Processing Record 33 of Set 7 | mjolby
# Processing Record 34 of Set 7 | lewistown
# Processing Record 35 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 7 | azul
# Processing Record 37 of Set 7 | san patricio
# Processing Record 38 of Set 7 | vestmannaeyjar
# Processing Record 39 of Set 7 | awjilah
# Processing Record 40 of Set 7 | aldan
# Processing Record 41 of Set 7 | vila franca do campo
# Processing Record 42 of Set 7 | severo-kurilsk
# Processing Record 43 of Set 7 | port lincoln
# Processing Record 44 of Set 7 | san andres
# Processing Record 45 of Set 7 | khorramshahr
# Processing Record 46 of Set 7 | ayagoz
# Processing Record 47 of Set 7 | korla
# Processing Record 48 of Set 7 | college
# Processing Record 49 of Set 7 | caravelas
# Processing Record 50 of Set 7 | kosum phisai
# Processing Record 1 of Set 8 | kimbe
# Processing Record 2 of Set 8 | chapais
# Processing Record 3 of Set 8 | pervomayskiy
# Processing Record 4 of Set 8 | luena
# Processing Record 5 of Set 8 | westport
# Processing Record 6 of Set 8 | port alberni
# Processing Record 7 of Set 8 | port-gentil
# Processing Record 8 of Set 8 | hamilton
# Processing Record 9 of Set 8 | grand-santi
# Processing Record 10 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 8 | daru
# Processing Record 13 of Set 8 | leeuwarden
# Processing Record 14 of Set 8 | xingyi
# Processing Record 15 of Set 8 | linjiang
# Processing Record 16 of Set 8 | deputatskiy
# Processing Record 17 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 8 | mineral wells
# Processing Record 19 of Set 8 | san jeronimo
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | takoradi
# Processing Record 22 of Set 8 | paracuru
# Processing Record 23 of Set 8 | necochea
# Processing Record 24 of Set 8 | seddon
# Processing Record 25 of Set 8 | portree
# Processing Record 26 of Set 8 | aban
# Processing Record 27 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 8 | conde
# Processing Record 29 of Set 8 | tonaya
# Processing Record 30 of Set 8 | doha
# Processing Record 31 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 32 of Set 8 | iqaluit
# Processing Record 33 of Set 8 | honiara
# Processing Record 34 of Set 8 | ferrol
# Processing Record 35 of Set 8 | upington
# Processing Record 36 of Set 8 | khammam
# Processing Record 37 of Set 8 | talnakh
# Processing Record 38 of Set 8 | buraydah
# Processing Record 39 of Set 8 | eyl
# Processing Record 40 of Set 8 | acuna
# City not found. Skipping...
# Processing Record 41 of Set 8 | redlands
# Processing Record 42 of Set 8 | udachnyy
# Processing Record 43 of Set 8 | sainte-maxime
# Processing Record 44 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 8 | lagoa
# Processing Record 46 of Set 8 | alvaraes
# Processing Record 47 of Set 8 | nouadhibou
# Processing Record 48 of Set 8 | carutapera
# Processing Record 49 of Set 8 | gulu
# Processing Record 50 of Set 8 | sangar
# Processing Record 1 of Set 9 | nioro
# Processing Record 2 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 3 of Set 9 | sao paulo de olivenca
# Processing Record 4 of Set 9 | oltu
# Processing Record 5 of Set 9 | pemba
# Processing Record 6 of Set 9 | batagay
# Processing Record 7 of Set 9 | ion corvin
# Processing Record 8 of Set 9 | tahe
# Processing Record 9 of Set 9 | ahipara
# Processing Record 10 of Set 9 | zaykovo
# Processing Record 11 of Set 9 | mahibadhoo
# Processing Record 12 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 9 | yurimaguas
# Processing Record 14 of Set 9 | alliance
# Processing Record 15 of Set 9 | bubaque
# Processing Record 16 of Set 9 | trairi
# Processing Record 17 of Set 9 | marawi
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | manjacaze
# Processing Record 20 of Set 9 | abdulino
# Processing Record 21 of Set 9 | sakata
# Processing Record 22 of Set 9 | yumen
# Processing Record 23 of Set 9 | sohag
# Processing Record 24 of Set 9 | olinda
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | play cu
# City not found. Skipping...
# Processing Record 27 of Set 9 | manavgat
# Processing Record 28 of Set 9 | praia
# Processing Record 29 of Set 9 | cap malheureux
# Processing Record 30 of Set 9 | manokwari
# Processing Record 31 of Set 9 | hovd
# Processing Record 32 of Set 9 | finschhafen
# Processing Record 33 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 9 | faya
# Processing Record 35 of Set 9 | pisco
# Processing Record 36 of Set 9 | ulladulla
# Processing Record 37 of Set 9 | shelburne
# Processing Record 38 of Set 9 | dali
# Processing Record 39 of Set 9 | moulins
# Processing Record 40 of Set 9 | gazojak
# Processing Record 41 of Set 9 | quang ngai
# Processing Record 42 of Set 9 | hervey bay
# Processing Record 43 of Set 9 | hailar
# Processing Record 44 of Set 9 | le port
# Processing Record 45 of Set 9 | mandvi
# Processing Record 46 of Set 9 | lyngseidet
# Processing Record 47 of Set 9 | benguela
# Processing Record 48 of Set 9 | namibe
# Processing Record 49 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 9 | aripuana
# Processing Record 1 of Set 10 | bozuyuk
# Processing Record 2 of Set 10 | carnarvon
# Processing Record 3 of Set 10 | lyubech
# Processing Record 4 of Set 10 | sochi
# Processing Record 5 of Set 10 | jovellar
# Processing Record 6 of Set 10 | barranco de loba
# Processing Record 7 of Set 10 | agadir
# Processing Record 8 of Set 10 | mandurah
# Processing Record 9 of Set 10 | vao
# Processing Record 10 of Set 10 | naila
# Processing Record 11 of Set 10 | orem
# Processing Record 12 of Set 10 | upata
# Processing Record 13 of Set 10 | novyy urengoy
# Processing Record 14 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 15 of Set 10 | hamada
# Processing Record 16 of Set 10 | kaseda
# Processing Record 17 of Set 10 | hailun
# Processing Record 18 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 19 of Set 10 | caluquembe
# Processing Record 20 of Set 10 | chigorodo
# Processing Record 21 of Set 10 | maceio
# Processing Record 22 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 10 | praya
# Processing Record 24 of Set 10 | beira
# Processing Record 25 of Set 10 | cordele
# Processing Record 26 of Set 10 | leningradskiy
# Processing Record 27 of Set 10 | ucluelet
# Processing Record 28 of Set 10 | khudumelapye
# Processing Record 29 of Set 10 | yasnyy
# Processing Record 30 of Set 10 | bandarban
# Processing Record 31 of Set 10 | panguna
# Processing Record 32 of Set 10 | clermont
# Processing Record 33 of Set 10 | emerald
# Processing Record 34 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 10 | taman
# Processing Record 36 of Set 10 | dunedin
# Processing Record 37 of Set 10 | sault sainte marie
# Processing Record 38 of Set 10 | tete
# Processing Record 39 of Set 10 | kyrylivka
# Processing Record 40 of Set 10 | castelo branco
# Processing Record 41 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 42 of Set 10 | gizo
# Processing Record 43 of Set 10 | axim
# Processing Record 44 of Set 10 | pasinler
# Processing Record 45 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 10 | husavik
# Processing Record 47 of Set 10 | xuddur
# Processing Record 48 of Set 10 | oudtshoorn
# Processing Record 49 of Set 10 | la ronge
# Processing Record 50 of Set 10 | emba
# Processing Record 1 of Set 11 | khasan
# Processing Record 2 of Set 11 | darnah
# Processing Record 3 of Set 11 | sechura
# Processing Record 4 of Set 11 | sinnamary
# Processing Record 5 of Set 11 | norman wells
# Processing Record 6 of Set 11 | flinders
# Processing Record 7 of Set 11 | paita
# Processing Record 8 of Set 11 | kuliyapitiya
# Processing Record 9 of Set 11 | lilongwe
# Processing Record 10 of Set 11 | luba
# Processing Record 11 of Set 11 | nanortalik
# Processing Record 12 of Set 11 | hobyo
# Processing Record 13 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 11 | acurenam
# Processing Record 15 of Set 11 | el alto
# Processing Record 16 of Set 11 | cascavel
# Processing Record 17 of Set 11 | sawtell
# Processing Record 18 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 11 | nome
# Processing Record 20 of Set 11 | muros
# Processing Record 21 of Set 11 | manta
# Processing Record 22 of Set 11 | robore
# Processing Record 23 of Set 11 | porto novo
# Processing Record 24 of Set 11 | xingcheng
# Processing Record 25 of Set 11 | quthing
# Processing Record 26 of Set 11 | nizhniy kuranakh
# Processing Record 27 of Set 11 | dvinskoy
# Processing Record 28 of Set 11 | venado tuerto
# Processing Record 29 of Set 11 | valleyview
# Processing Record 30 of Set 11 | nazira
# Processing Record 31 of Set 11 | teguldet
# Processing Record 32 of Set 11 | markova
# Processing Record 33 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 11 | golpayegan
# Processing Record 35 of Set 11 | hasilpur
# Processing Record 36 of Set 11 | ballina
# Processing Record 37 of Set 11 | cassia
# Processing Record 38 of Set 11 | montes claros
# Processing Record 39 of Set 11 | la victoria
# Processing Record 40 of Set 11 | summerside
# Processing Record 41 of Set 11 | kambja
# Processing Record 42 of Set 11 | bani walid
# Processing Record 43 of Set 11 | broken hill
# Processing Record 44 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 11 | tomatlan
# Processing Record 46 of Set 11 | kyabe
# Processing Record 47 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 11 | snezhnogorsk
# Processing Record 49 of Set 11 | sandwick
# Processing Record 50 of Set 11 | illapel
# Processing Record 1 of Set 12 | corinto
# Processing Record 2 of Set 12 | penzance
# Processing Record 3 of Set 12 | leshukonskoye
# Processing Record 4 of Set 12 | solnechnyy
# Processing Record 5 of Set 12 | storforshei
# Processing Record 6 of Set 12 | saint anthony
# Processing Record 7 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 8 of Set 12 | holland
# Processing Record 9 of Set 12 | tyukhtet
# Processing Record 10 of Set 12 | kirakira
# Processing Record 11 of Set 12 | leninsk
# Processing Record 12 of Set 12 | jodhpur
# Processing Record 13 of Set 12 | pamplona
# Processing Record 14 of Set 12 | lahuachaca
# Processing Record 15 of Set 12 | nhulunbuy
# Processing Record 16 of Set 12 | almaznyy
# Processing Record 17 of Set 12 | kayerkan
# Processing Record 18 of Set 12 | palu
# Processing Record 19 of Set 12 | asfi
# Processing Record 20 of Set 12 | cuajinicuilapa
# Processing Record 21 of Set 12 | vinh
# Processing Record 22 of Set 12 | kidal
# Processing Record 23 of Set 12 | rawson
# Processing Record 24 of Set 12 | kawalu
# Processing Record 25 of Set 12 | chicama
# Processing Record 26 of Set 12 | vila velha
# Processing Record 27 of Set 12 | margate
# Processing Record 28 of Set 12 | gorin
# Processing Record 29 of Set 12 | lata
# Processing Record 30 of Set 12 | aktash
# Processing Record 31 of Set 12 | itanhaem
# Processing Record 32 of Set 12 | itarema
# Processing Record 33 of Set 12 | muana
# Processing Record 34 of Set 12 | alice town
# Processing Record 35 of Set 12 | havre
# Processing Record 36 of Set 12 | bafq
# Processing Record 37 of Set 12 | bafoulabe
# Processing Record 38 of Set 12 | luderitz
# Processing Record 39 of Set 12 | portpatrick
# City not found. Skipping...
# Processing Record 40 of Set 12 | zhanaozen
# Processing Record 41 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 42 of Set 12 | khani
# Processing Record 43 of Set 12 | lerwick
# Processing Record 44 of Set 12 | chulman
# Processing Record 45 of Set 12 | galesong
# Processing Record 46 of Set 12 | samarai
# Processing Record 47 of Set 12 | ankara
# Processing Record 48 of Set 12 | shache
# Processing Record 49 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 12 | ruwi
# Processing Record 1 of Set 13 | fort nelson
# Processing Record 2 of Set 13 | codrington
# Processing Record 3 of Set 13 | bezhetsk
# Processing Record 4 of Set 13 | saint-pierre
# Processing Record 5 of Set 13 | ugoofaaru
# Processing Record 6 of Set 13 | hvammstangi
# City not found. Skipping...
# Processing Record 7 of Set 13 | linguere
# Processing Record 8 of Set 13 | sur
# Processing Record 9 of Set 13 | a
# City not found. Skipping...
# Processing Record 10 of Set 13 | morehead
# Processing Record 11 of Set 13 | carbonia
# Processing Record 12 of Set 13 | saldanha
# Processing Record 13 of Set 13 | richards bay
# Processing Record 14 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 13 | matay
# Processing Record 16 of Set 13 | osypenko
# Processing Record 17 of Set 13 | kiunga
# Processing Record 18 of Set 13 | shingu
# Processing Record 19 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 20 of Set 13 | mujiayingzi
# Processing Record 21 of Set 13 | santa isabel
# Processing Record 22 of Set 13 | togur
# Processing Record 23 of Set 13 | mildura
# Processing Record 24 of Set 13 | kilindoni
# Processing Record 25 of Set 13 | mundgod
# Processing Record 26 of Set 13 | macomb
# Processing Record 27 of Set 13 | bambui
# Processing Record 28 of Set 13 | kantang
# Processing Record 29 of Set 13 | port blair
# Processing Record 30 of Set 13 | malartic
# Processing Record 31 of Set 13 | launceston
# Processing Record 32 of Set 13 | winnemucca
# Processing Record 33 of Set 13 | manakara
# Processing Record 34 of Set 13 | yeppoon
# Processing Record 35 of Set 13 | loandjili
# Processing Record 36 of Set 13 | hendek
# Processing Record 37 of Set 13 | souillac
# Processing Record 38 of Set 13 | oranjemund
# Processing Record 39 of Set 13 | punta alta
# Processing Record 40 of Set 13 | kupang
# Processing Record 41 of Set 13 | sayyan
# Processing Record 42 of Set 13 | sao felix do xingu
# Processing Record 43 of Set 13 | kaliua
# Processing Record 44 of Set 13 | puerto quijarro
# Processing Record 45 of Set 13 | gravdal
# Processing Record 46 of Set 13 | bara
# Processing Record 47 of Set 13 | porangatu
# Processing Record 48 of Set 13 | eirunepe
# Processing Record 49 of Set 13 | kangaatsiaq
# Processing Record 50 of Set 13 | beaverlodge
# Processing Record 1 of Set 14 | kadyy
# Processing Record 2 of Set 14 | nayoro
# Processing Record 3 of Set 14 | kannur
# Processing Record 4 of Set 14 | raudeberg
# Processing Record 5 of Set 14 | churapcha
# Processing Record 6 of Set 14 | liverpool
# Processing Record 7 of Set 14 | kavaratti
# Processing Record 8 of Set 14 | russell
# Processing Record 9 of Set 14 | santa isabel do rio negro
# Processing Record 10 of Set 14 | pajarito
# Processing Record 11 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 14 | bajil
# Processing Record 13 of Set 14 | ushtobe
# Processing Record 14 of Set 14 | bosaso
# Processing Record 15 of Set 14 | mier
# Processing Record 16 of Set 14 | aloleng
# Processing Record 17 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 14 | calvinia
# Processing Record 19 of Set 14 | kalmar
# Processing Record 20 of Set 14 | vardo
# Processing Record 21 of Set 14 | kholm
# Processing Record 22 of Set 14 | naze
# Processing Record 23 of Set 14 | prince albert
# Processing Record 24 of Set 14 | tautira
# Processing Record 25 of Set 14 | coihaique
# Processing Record 26 of Set 14 | karratha
# Processing Record 27 of Set 14 | cap-aux-meules
# Processing Record 28 of Set 14 | parana
# Processing Record 29 of Set 14 | leo
# Processing Record 30 of Set 14 | vestmanna
# Processing Record 31 of Set 14 | ginir
# Processing Record 32 of Set 14 | blagoyevo
# Processing Record 33 of Set 14 | tamiahua
# Processing Record 34 of Set 14 | motema
# Processing Record 35 of Set 14 | mahanje
# Processing Record 36 of Set 14 | balurghat
# Processing Record 37 of Set 14 | broadstairs
# Processing Record 38 of Set 14 | state college
# Processing Record 39 of Set 14 | general roca
# Processing Record 40 of Set 14 | sciacca
# Processing Record 41 of Set 14 | vila
# Processing Record 42 of Set 14 | wa
# City not found. Skipping...
# Processing Record 43 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 14 | sumbe
# Processing Record 45 of Set 14 | topolobampo
# Processing Record 46 of Set 14 | dolores hidalgo
# Processing Record 47 of Set 14 | kang
# Processing Record 48 of Set 14 | opelousas
# Processing Record 49 of Set 14 | ponta delgada
# Processing Record 50 of Set 14 | proletarsk
# Processing Record 1 of Set 15 | shostka
# Processing Record 2 of Set 15 | oranjestad
# Processing Record 3 of Set 15 | mirnyy
# Processing Record 4 of Set 15 | egvekinot
# Processing Record 5 of Set 15 | belaya gora
# Processing Record 6 of Set 15 | puerto escondido
# Processing Record 7 of Set 15 | milkovo
# Processing Record 8 of Set 15 | moree
# Processing Record 9 of Set 15 | ormara
# Processing Record 10 of Set 15 | sao desiderio
# Processing Record 11 of Set 15 | rio gallegos
# Processing Record 12 of Set 15 | sosnovo-ozerskoye
# Processing Record 13 of Set 15 | yelan
# Processing Record 14 of Set 15 | lanxi
# Processing Record 15 of Set 15 | otjimbingwe
# Processing Record 16 of Set 15 | letpadan
# Processing Record 17 of Set 15 | virginia beach
# Processing Record 18 of Set 15 | pestyaki
# Processing Record 19 of Set 15 | evensk
# Processing Record 20 of Set 15 | mersing
# Processing Record 21 of Set 15 | verkhnevilyuysk
# Processing Record 22 of Set 15 | yelyzavethradka
# Processing Record 23 of Set 15 | howell
# Processing Record 24 of Set 15 | muroto
# Processing Record 25 of Set 15 | vilhena
# Processing Record 26 of Set 15 | kuybyshevo
# Processing Record 27 of Set 15 | krasnoselkup
# Processing Record 28 of Set 15 | san fernando
# Processing Record 29 of Set 15 | locri
# Processing Record 30 of Set 15 | saint-paul
# Processing Record 31 of Set 15 | boueni
# Processing Record 32 of Set 15 | manicore
# Processing Record 33 of Set 15 | vasilyevskiy mokh
# Processing Record 34 of Set 15 | saint-francois
# Processing Record 35 of Set 15 | himatangi
# Processing Record 36 of Set 15 | zhangjiakou
# Processing Record 37 of Set 15 | soroca
# Processing Record 38 of Set 15 | jazzin
# City not found. Skipping...
# Processing Record 39 of Set 15 | acarau
# Processing Record 40 of Set 15 | cay
# Processing Record 41 of Set 15 | andarab
# City not found. Skipping...
# Processing Record 42 of Set 15 | wainwright
# Processing Record 43 of Set 15 | poum
# Processing Record 44 of Set 15 | peniche
# Processing Record 45 of Set 15 | winneba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Port Alfred -33.59   26.89     68.41        90           1        7.56
# 1    Punta Arenas -53.15  -70.92     60.80        51          40       31.09
# 2         Ushuaia -54.80  -68.30     60.80        41          75       12.75
# 3      Georgetown   5.41  100.34     78.80        88          40        3.36
# 4       Hithadhoo  -0.60   73.08     82.87        74          89        9.75
# 5        San Luis -33.30  -66.34     83.71        25          62        8.21
# 6      Banda Aceh   5.56   95.32     78.46        79          99        2.37
# 7    Ponta Do Sol  32.67  -17.10     66.20        72          40        4.70
# 8          Kodiak  57.79 -152.41     42.80        81          90        3.36
# 9  Cabo San Lucas  22.89 -109.91     84.00        65          40       10.29
#
#   Country Current Description
# 0      ZA           clear sky
# 1      CL    scattered clouds
# 2      AR       broken clouds
# 3      MY          light rain
# 4      MV       moderate rain
# 5      AR       broken clouds
# 6      ID     overcast clouds
# 7      PT    scattered clouds
# 8      US          light rain
# 9      MX    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Vacation.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
